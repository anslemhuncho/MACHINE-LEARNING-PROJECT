# %% [markdown]
# <a href="https://colab.research.google.com/github/anslemhuncho/MACHINE-LEARNING-PROJECT/blob/main/EDA_machine_L.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install imagehash
import imagehash
from PIL import Image
import imagehash
from tqdm import tqdm
import shutil
import os
original_data = '/content/drive/MyDrive/crowd prediction/SensitiveScene'
formatted_data = '/content/drive/MyDrive/normalised data'
dir = formatted_data

for subdir in os.listdir(original_data):
    src_dir = os.path.join(original_data, subdir)
    dest_dir = os.path.join(dir, subdir)

    if os.path.isdir(src_dir):
        if not os.path.exists(dest_dir):
            os.makedirs(dest_dir, exist_ok=True)

        for img in os.listdir(src_dir):
            src_path = os.path.join(src_dir, img)
            dest_path = os.path.join(dest_dir, img)

            if os.path.isfile(src_path):
                shutil.copy2(src_path, dest_path)
                print(f'Copied image {src_path} to {dest_path}')
            else:
                print(f'image already present at {dest_path}')

# %%
from PIL import Image

import os

# Assign a valid path to the dir variable
dir = '/content/drive/MyDrive/normalised data'

from PIL import Image

def resize_image(input_path):
    if input_path.lower().endswith(('.png', '.jpg', '.jpeg')):
        original = Image.open(input_path)
        new = original.resize((254, 254))
        new.save(input_path)
        print(f'resized image at {input_path}')

for subdir in os.listdir(dir):
    dest_dir = os.path.join(dir, subdir)
    if os.path.isdir(dest_dir):
        for img in os.listdir(dest_dir):
          img_path = os.path.join(dest_dir, img)
          resize_image(img_path)
# Out:
# resized image at /content/drive/MyDrive/normalised data/immigration/2c5af74ff78d521beaed866bb92555c988cb1b40.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/29c7dce7f7bc9aa3697677de2c6f2b4054411506.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/25062895cc6543226e4605a12583848c599c378f.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/0c5af07538ea5e714746b44c439f7a38019e2fe6.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/5b7234fc71f65d01a7f532694163e8ad6a3406b3.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/54128b49f4e720841544f0b76ae7a1d0964b0469.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/5a9ac462f52fe854f3b6758ac4a87da830c245d2.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/8b726ef486b180aa5c99a2bc834c6ae86ee77392.jpg
# ...

# %%
from PIL import Image

def resize_image(input_path):
    if input_path.lower().endswith(('.png', '.jpg', '.jpeg')):
        original = Image.open(input_path)
        new = original.resize((254, 254))
        new.save(input_path)
        print(f'resized image at {input_path}')

for subdir in os.listdir(dir):
    dest_dir = os.path.join(dir, subdir)
    if os.path.isdir(dest_dir):
        for img in os.listdir(dest_dir):
          img_path = os.path.join(dest_dir, img)
          resize_image(img_path)
# Out:
# resized image at /content/drive/MyDrive/normalised data/immigration/2c5af74ff78d521beaed866bb92555c988cb1b40.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/29c7dce7f7bc9aa3697677de2c6f2b4054411506.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/25062895cc6543226e4605a12583848c599c378f.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/0c5af07538ea5e714746b44c439f7a38019e2fe6.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/5b7234fc71f65d01a7f532694163e8ad6a3406b3.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/54128b49f4e720841544f0b76ae7a1d0964b0469.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/5a9ac462f52fe854f3b6758ac4a87da830c245d2.jpg
# resized image at /content/drive/MyDrive/normalised data/immigration/8b726ef486b180aa5c99a2bc834c6ae86ee77392.jpg
# ...

# %%
# !pip install google-api-python-client

# %%
def count_images(directory):
    image_count = 0
    for filename in os.listdir(directory):
        img_path = os.path.join(directory, filename)
        if os.path.isfile(img_path) and filename.lower().endswith(('.png', '.jpg', '.jpeg')):
            image_count += 1
    return image_count

for subdir in os.listdir(dir):
    path = os.path.join(dir, subdir)
    if os.path.isdir(path):
        image_count = count_images(path)
        print(f"Images in {subdir}: {image_count}")
    else:
        print(f"{subdir} is not a directory.")
# Out:
# Images in immigration: 373
# Images in appealing_for_peace: 575
# Images in election: 446
# Images in gender_equality: 300
# Images in covid19: 287
# Images in yellow_vests_movement: 348
# Images in brexit: 547
# Images in animals_protection: 355
# Images in environment_protection: 393
# Images in racial_equality: 330
# Images in .ipynb_checkpoints: 0

# %%
print(dir)
for item in os.listdir(dir):
       print(item)
for item in os.listdir(dir):
       if os.path.isfile(os.path.join(dir, item)):
           ext = os.path.splitext(item)[1].lower()
           if ext not in ['.png', '.jpg', '.jpeg']:
               print(f"Skipping file '{item}' due to unsupported file type.")
print(os.stat(dir).st_mode)
# Out:
# /content/drive/MyDrive/normalised data
# animals_protection
# appealing_for_peace
# brexit
# covid19
# election
# environment_protection
# gender_equality
# immigration
# racial_equality
# yellow_vests_movement
# 16832

# %%
import matplotlib.pyplot as plt

Categories = []
Category_image_count = []

# Iterate through each subdirectory
for subdir in os.listdir(dir):
    subdir_path = os.path.join(dir, subdir)
    if os.path.isdir(subdir_path):
        count_images = len([file for file in os.listdir(subdir_path)
                          if file.lower().endswith(('.png', '.jpg', '.jpeg'))])
        Categories.append(subdir)
        Category_image_count.append(count_images)

# Create a bar chart to visualize the distribution of images
plt.figure(figsize=(10, 6))
plt.bar(Categories, Category_image_count, color='maroon')
plt.xlabel('CATEGORY')
plt.ylabel('NUMBER OF IMAGES')
plt.title('Distribution of Images in Election directory')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
import os
import plotly.express as px

image_sizes = []

for subdir in os.listdir(dir):
    subdir_path = os.path.join(dir, subdir)
    if os.path.isdir(subdir_path):
        for img in os.listdir(subdir_path):
            img_path = os.path.join(subdir_path,img)
            if img_path.lower().endswith(('.png', '.jpg', '.jpeg')):
                size = os.path.getsize(img_path)
                image_sizes.append(size / 1_000_000)  # Convert bytes to megabytes

# Create a histogram to visualize the distribution of image sizes
fig = px.histogram(x=image_sizes, nbins=50, title="Distribution of Image Sizes")
fig.update_layout(
    title='Distribution of Image Sizes',
    xaxis_title='Image Size (MB)',
    yaxis_title='Frequency',
    showlegend=False,
    bargap=0.1,
    bargroupgap=0.1
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

class_names = []
for subdir in os.listdir(dir):
  class_names.append(subdir)

labels = np.random.choice(class_names,len(class_names))
df = pd.get_dummies(labels, columns=class_names)
correlation_matrix = df.corr()

plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap between Labels')
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt

class_names = os.listdir(dir)
num_classes = len(class_names)
num_rows = (num_classes // 3) + (1 if num_classes % 3 != 0 else 0)
num_cols = min(num_classes, 3)

plt.figure(figsize=(16, 16))  # Adjust the figure size to make the subplots bigger

for i, class_name in enumerate(class_names):
    class_dir = os.path.join(dir, class_name)
    sample_image_files = os.listdir(class_dir)

    # Check if there are any sample images for the current class
    if sample_image_files:
        sample_image_path = os.path.join(class_dir, sample_image_files[0])
        sample_image = cv2.imread(sample_image_path)
        sample_image = cv2.cvtColor(sample_image, cv2.COLOR_BGR2RGB)
        plt.subplot(num_rows, num_cols, i+1)
        plt.imshow(sample_image)
        plt.title(class_name)
        plt.axis('off')
